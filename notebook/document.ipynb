# %% [markdown]
# ### Data Ingestion

# %%
from langchain_community.utilities.pebblo import dir_loader
# document dataStructure

from langchain_core.documents import Document
from sqlalchemy.testing.suite.test_reflection import metadata

# %%
# just to understand how the doc works
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Imon Hosen",
        "date_create" :"2024-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Imon Hosen', 'date_create': '2024-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
# Create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
# some sample text

sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",



    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems


    """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created!")
# Out:
# Sample text files created!

# %%
## Text loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")

document = loader.load()

document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # pattern to match files
    loader_cls=TextLoader,
    loader_kwargs=dict(encoding="utf-8"),
    show_progress = False
)
doc_txt = dir_loader.load()
doc_txt
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %%
## Pdf loader

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", # pattern to match files
    loader_cls = PyMuPDFLoader, # loader class to use
    #loader_kwargs = dict(encoding="utf-8"),
    show_progress = False
)
doc_pdf = dir_loader.load()
doc_pdf
# Out:
# [Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 1}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 2}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 3}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 4}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 5}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 6}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 7}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 8}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 9}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 10}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 11}, page_content=''),
#  Document(metadata={'producer': 'macOS Version 15.1.1 (Build 24B91) Quartz PDFContext', 'creator': '', 'creationdate': "D:20250425210232Z00'00'", 'source': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'file_path': '../data/pdf/9_Counterintuitive_Investment_Principles_from_Mohnish_Pabrai.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250425210232Z00'00'", 'trapped': '', 'modDate': "D:20250425210232Z00'00'", 'creationDate': "D:20250425210232Z00'00'", 'page': 12}, page_content=''),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '2025-11-16T11:41:55+00:00', 'source': '../data/pdf/start_hamburg.pdf', 'file_path': '../data/pdf/start_hamburg.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-16T11:41:55+00:00', 'trapped': '', 'modDate': "D:20251116114155+00'00'", 'creationDate': "D:20251116114155+00'00'", 'page': 0}, page_content='Imon Hosen: Information Engineering\nJourney\nFrom Bangladesh to Germany, pursuing a B.Eng. in \nInformation Engineering.\nCore Passion\nDriven by the intersection of Software, Data, and Machine \nMachine Learning.\nProblem Solver\nA hands-on approach to turning complex technology into real\ninto real-\n-\nworld solutions.\nValue Creation\nMotivated to create value in both corporate and \nentrepreneurial settings.\nDhaka, \nBangladesh\nHamburg, Germany\n1'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '2025-11-16T11:41:55+00:00', 'source': '../data/pdf/start_hamburg.pdf', 'file_path': '../data/pdf/start_hamburg.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-16T11:41:55+00:00', 'trapped': '', 'modDate': "D:20251116114155+00'00'", 'creationDate': "D:20251116114155+00'00'", 'page': 1}, page_content='From CS to Cybersecurity AI -- my background  \nMy academic and professional path is focused on translating advanced data concepts into high-impact business tools.\n1\nAcademic Path\nComputer Science (Bangladesh) leading to Information Engineering \n(Germany).\n2\nAI Focus\nElectives in Neural Networks, Machine Learning, and Data Science.\nScience.\n3\nSiemens Experience\nBuilding internal AI tools specifically for Operational Technology (OT) \nTechnology (OT) Cybersecurity.\n4\nOlympus Role\nData Analytics and support for Professional Education initiatives.\ninitiatives.\n2'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '2025-11-16T11:41:55+00:00', 'source': '../data/pdf/start_hamburg.pdf', 'file_path': '../data/pdf/start_hamburg.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-16T11:41:55+00:00', 'trapped': '', 'modDate': "D:20251116114155+00'00'", 'creationDate': "D:20251116114155+00'00'", 'page': 2}, page_content='The “Bicycle Principle” -- My Desire to Grow with START \n“Life is like a bicycle — keep moving or fall.”\nI embrace a growth mindset, constantly seeking movement and mastery through new challenges.\nGrowth Mindset\nPushing beyond the comfort zone to acquire \nacquire new skills.\nCompetitive Drive\nTesting limits in a real-world, market-driven \nenvironment.\nCommunity Building\nForging lasting connections with ambitious, \nambitious, like-minded peers.\nEntrepreneurial Evolution\nSeeking continuous learning, feedback, and \ndevelopment.\n3'),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '2025-11-16T11:41:55+00:00', 'source': '../data/pdf/start_hamburg.pdf', 'file_path': '../data/pdf/start_hamburg.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-11-16T11:41:55+00:00', 'trapped': '', 'modDate': "D:20251116114155+00'00'", 'creationDate': "D:20251116114155+00'00'", 'page': 3}, page_content='Entrepreneurial talent\nI possess the dual skillset of engineering precision and entrepreneurial execution.\nAction-First\nRunning a small business (T-\nshirts & UI/UX design) in \nshirts \nBangladesh.\nTechnical Depth\nProven AI tools development \ncapabilities from my experience at \nexperience at Siemens.\nExecution Focus\nAbility to turn initial ideas into \ninto working, scalable solutions.\nsolutions.\nDual Skillset\nCombining engineering precision \nwith design and user experience \ninsight.\nMy mindset is not just to code, but to create, sell, and scale value.\n4')]

# %%
# excel reader

from langchain_community.document_loaders import DirectoryLoader, UnstructuredExcelLoader

dir_loader = DirectoryLoader(
    "../data/excel",  # Your Excel folder path
    glob="**/*.xlsx",  # Pattern to match Excel files
    loader_cls=UnstructuredExcelLoader,
    show_progress=False
)

doc_excel = dir_loader.load()
doc_excel
# Out:
# [Document(metadata={'source': '../data/excel/leads_2025-10-26_12-56-30.xlsx'}, page_content='name email phone address website facebook instagram description CODOS Coffee Bartelsstraße 26, Hamburg, Germany A minimalistic cafe offering discounts for reusable cups. Balz und Balz Lehmweg 6, Hamburg, Germany A cafe known for great reviews and delicious food, promoting eco-friendly coffee consumption. Playground Coffee Detlev-Bremer-Straße 21, St. Pauli, Hamburg, Germany A cafe in St. Pauli known for roasting coffee with love and passion. Klein und Kaiserlich Am Kaiserkai 26, 20457 Hamburg, Germany A coffee house offering traditional Austrian coffee specialties with a view of Vasco-da-Gama square. Café Unter den Linden Juliusstraße 16, 22769 Hamburg, Germany A quieter cafe in Hamburg known for its design and attention to detail. Gretchens Villa Marktstraße 142, 20357 Hamburg, Germany A cafe offering a French way of life with breakfast and tarts. Milch Ditmar-Koel-Straße 22, 20459 Hamburg, Germany https://www.instagram.com/milch A cafe known for its charm and fresh milk coffee drinks. Café Gnosa Lange Reihe 93, 20099 Hamburg, Germany A cafe offering breakfast, coffee, and cake in a relaxed atmosphere. Café Johanna Venusberg 26, 20459 Hamburg, Germany A peaceful cafe offering freshly prepared dishes in a relaxed atmosphere. Comfort Zone Cafe 17 Main Street, Hamburg, NY 14075, USA http://www.comfortzonecafe.com https://www.facebook.com/comfortzonecafe https://www.instagram.com/comfortzonecafe A cafe in Hamburg, NY offering homemade soups, sandwiches, and desserts.')]
